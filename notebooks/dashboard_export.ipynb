# %%
# --- Setup ---
import pandas as pd
from pybaseball import playerid_reverse_lookup

# Load the final Phase 4 combo recommendations
combos = pd.read_parquet("phase4_combo_recommendations.parquet")
print(f"Loaded {len(combos)} rows")
combos.head()
# Out:
# Loaded 3888 rows
#    pitcher stand    archetype pitch_1 pitch_2 pitch_3     score
# 0   453286     L  archetype_0      CH      FF      SL -0.006147
# 1   453286     L  archetype_1      CH      CU      FF -0.003971
# 2   453286     L  archetype_2      CH      CU      FF  0.008580
# 3   453286     L  archetype_3      CU      FF      SL -0.002692
# 4   453286     L  archetype_4      CH      CU      FF  0.022228
